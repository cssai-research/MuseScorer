# %%
from utils import *

# %%
if __name__ == "__main__":
    # set only these five variables
    llm_model = 'llama3.3' # phi4
    prompt_method = 'CoT' # choose between 'CoT' and 'baseline'. For qwen, the baseline itself is COT
    embedding_code = 1 # see dictionary below for options
    comparison_k = 10  # choose K_c
    replication_id = 2001 # seed for reordering the input idea file

    study_prefix = "s1_data_long"  # these must not change
    embedding_choice_dict = {
        1: "mixedbread-ai/mxbai-embed-large-v1", 
        2: "intfloat/e5-large-v2", 
        3: "all-mpnet-base-v2", 
        4: "BAAI/bge-large-en-v1.5"
    }
        
    # the rest will take care of itself
    for object_name in ["box","rope"]: 
        exp_arg = {
            'experiment_name': f"{study_prefix}_{llm_model.replace('.', '_').replace(':', '_')}_{prompt_method}_{object_name}_e{embedding_code}_k{comparison_k}_r{replication_id}",
            'object_name': object_name, 
            'input_csv_path': f"input_files/{study_prefix}_{object_name}.csv",
            'llm_model': llm_model, 
            'prompt_method': prompt_method,
            'replication_id': replication_id,
            'comparison_k': comparison_k,
            'save_csvs': True,
            'max_attempts':3,
            'embedding_model': embedding_choice_dict[embedding_code]
        }
        run_experiment(exp_arg)

# %%
if __name__ == "__main__":
    # set only these five variables
    llm_model = 'llama3.3' #  'llama3.3', 'qwen3', 'phi4'
    prompt_method = 'CoT' #choose between 'CoT' and 'baseline'. For qwen, the baseline itself is COT
    embedding_code = 1 # see dictionary below for options
    comparison_k = 10 # choose K_c
    replication_id = 2001 # seed for reordering the input idea file

    study_prefix = "s2_data_long" # these must not change
    embedding_choice_dict = {
        1: "mixedbread-ai/mxbai-embed-large-v1", 
        2: "intfloat/e5-large-v2", 
        3: "all-mpnet-base-v2", 
        4: "BAAI/bge-large-en-v1.5"
    }
        
    # the rest will take care of itself
    for object_name in ["box","rope"]: 
        exp_arg = {
            'experiment_name': f"{study_prefix}_{llm_model.replace('.', '_').replace(':', '_')}_{prompt_method}_{object_name}_e{embedding_code}_k{comparison_k}_r{replication_id}",
            'object_name': object_name, 
            'input_csv_path': f"input_files/{study_prefix}_{object_name}.csv",
            'llm_model': llm_model, 
            'prompt_method': prompt_method,
            'replication_id': replication_id,
            'comparison_k': comparison_k,
            'save_csvs': True,
            'max_attempts':3,
            'embedding_model': embedding_choice_dict[embedding_code]
        }
        run_experiment(exp_arg)

# %%
if __name__ == "__main__":
    # set only these five variables
    llm_model = 'llama3.3' #  'llama3.3', 'qwen3', 'phi4'
    prompt_method = 'CoT' # choose between 'CoT' and 'baseline'. For qwen, the baseline itself is COT
    embedding_code = 1 # see dictionary below for options
    comparison_k = 10 # choose K_c
    replication_id = 2001 # seed for reordering the input idea file

    study_prefix = "s3_data_long" # these must not change
    embedding_choice_dict = {
        1: "mixedbread-ai/mxbai-embed-large-v1", 
        2: "intfloat/e5-large-v2", 
        3: "all-mpnet-base-v2", 
        4: "BAAI/bge-large-en-v1.5"
    }
        
    # the rest will take care of itself
    for object_name in ["brick"]: 
        exp_arg = {
            'experiment_name': f"{study_prefix}_{llm_model.replace('.', '_').replace(':', '_')}_{prompt_method}_{object_name}_e{embedding_code}_k{comparison_k}_r{replication_id}",
            'object_name': object_name, 
            'input_csv_path': f"input_files/{study_prefix}_{object_name}.csv",
            'llm_model': llm_model, 
            'prompt_method': prompt_method,
            'replication_id': replication_id,
            'comparison_k': comparison_k,
            'save_csvs': True,
            'max_attempts':3,
            'embedding_model': embedding_choice_dict[embedding_code]
        }
        run_experiment(exp_arg)

# %%
if __name__ == "__main__":
    # set only these five variables
    llm_model = 'llama3.3' #  'llama3.3', 'qwen3', 'phi4'
    prompt_method = 'CoT' # choose between 'CoT' and 'baseline'. For qwen, the baseline itself is COT
    embedding_code = 1 # see dictionary below for options
    comparison_k = 10 # choose K_c
    replication_id = 2001 # seed for reordering the input idea file

    study_prefix = "HMSL_originality" # these must not change
    embedding_choice_dict = {
        1: "mixedbread-ai/mxbai-embed-large-v1", 
        2: "intfloat/e5-large-v2", 
        3: "all-mpnet-base-v2", 
        4: "BAAI/bge-large-en-v1.5"
    }
        
    # the rest will take care of itself
    for object_name in ["brick","paperclip"]: 
        exp_arg = {
            'experiment_name': f"{study_prefix}_{llm_model.replace('.', '_').replace(':', '_')}_{prompt_method}_{object_name}_e{embedding_code}_k{comparison_k}_r{replication_id}",
            'object_name': object_name, 
            'input_csv_path': f"input_files/{study_prefix}_{object_name}.csv",
            'llm_model': llm_model, 
            'prompt_method': prompt_method,
            'replication_id': replication_id,
            'comparison_k': comparison_k,
            'save_csvs': True,
            'max_attempts':3,
            'embedding_model': embedding_choice_dict[embedding_code]
        }
        run_experiment(exp_arg)
